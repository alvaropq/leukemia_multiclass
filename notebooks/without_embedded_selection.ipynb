# %%
import pandas as pd

# %%
df = pd.read_csv('correlation_variance_filter/flat/GSE13159.csv')

# %%
from hierarchical_model import HierarquicalClassifier

from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# %%
y = df['class']
X = df.drop('class',axis=1)

# %% [markdown]
# Adaboosting

# %%
clf = AdaBoostClassifier(estimator = DecisionTreeClassifier(),n_estimators=100, random_state=0)

# %%
lst_accu_stratified = []
lst_prec_stratified = []
lst_rec_stratified = []
lst_fscore_stratified = []

# %%
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=1)

for train_index, test_index in skf.split(X, y):
    x_train_fold, x_test_fold = X.iloc[train_index], X.iloc[test_index]
    y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]
    clf.fit(x_train_fold, y_train_fold)
    lst_accu_stratified.append(accuracy_score(y_test_fold,clf.predict(x_test_fold)))
    lst_prec_stratified.append(precision_score(y_test_fold,clf.predict(x_test_fold), average = 'weighted'))
    lst_rec_stratified.append(recall_score(y_test_fold,clf.predict(x_test_fold), average = 'weighted'))
    lst_fscore_stratified.append(f1_score(y_test_fold,clf.predict(x_test_fold), average = 'weighted'))

# %%
acc = (sum(lst_accu_stratified)/len(lst_accu_stratified))
prec = (sum(lst_prec_stratified)/len(lst_prec_stratified))
rec = (sum(lst_rec_stratified)/len(lst_rec_stratified))
f1 = (sum(lst_fscore_stratified)/len(lst_fscore_stratified))
dict1 = {"Metric": ["Accuracy", "Precision", "Recall", "F1"], "Score":[acc,prec,rec,f1]}

metrics = pd.DataFrame(dict1)

# %%
metrics
# Out:
#       Metric     Score
# 0   Accuracy  0.721355
# 1  Precision  0.724283
# 2     Recall  0.721355
# 3         F1  0.720635

# %%
clf.fit(X, y)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(), n_estimators=100,
#                    random_state=0)

# %% [markdown]
# Random Forest

# %%
clf = RandomForestClassifier(bootstrap = True,
 max_depth = 50,
 max_features = 'auto',
 min_samples_leaf = 1,
 min_samples_split = 2,
 n_estimators = 1000)

# %%
lst_accu_stratified = []
lst_prec_stratified = []
lst_rec_stratified = []
lst_fscore_stratified = []

# %%
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=1)

for train_index, test_index in skf.split(X, y):
    x_train_fold, x_test_fold = X.iloc[train_index], X.iloc[test_index]
    y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]
    clf.fit(x_train_fold, y_train_fold)
    lst_accu_stratified.append(accuracy_score(y_test_fold,clf.predict(x_test_fold)))
    lst_prec_stratified.append(precision_score(y_test_fold,clf.predict(x_test_fold), average = 'weighted'))
    lst_rec_stratified.append(recall_score(y_test_fold,clf.predict(x_test_fold), average = 'weighted'))
    lst_fscore_stratified.append(f1_score(y_test_fold,clf.predict(x_test_fold), average = 'weighted'))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
acc = (sum(lst_accu_stratified)/len(lst_accu_stratified))
prec = (sum(lst_prec_stratified)/len(lst_prec_stratified))
rec = (sum(lst_rec_stratified)/len(lst_rec_stratified))
f1 = (sum(lst_fscore_stratified)/len(lst_fscore_stratified))
dict1 = {"Metric": ["Accuracy", "Precision", "Recall", "F1"], "Score":[acc,prec,rec,f1]}

metrics = pd.DataFrame(dict1)

# %%
metrics
# Out:
#       Metric     Score
# 0   Accuracy  0.788171
# 1  Precision  0.754842
# 2     Recall  0.788171
# 3         F1  0.745234

# %%
clf.fit(X, y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# RandomForestClassifier(max_depth=50, max_features='auto', n_estimators=1000)

# %% [markdown]
# SVM

# %%
clf = SVC(kernel='linear', decision_function_shape='ovr',probability=True)

# %%
lst_accu_stratified = []
lst_prec_stratified = []
lst_rec_stratified = []
lst_fscore_stratified = []

# %%
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=1)

for train_index, test_index in skf.split(X, y):
    x_train_fold, x_test_fold = X.iloc[train_index], X.iloc[test_index]
    y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]
    clf.fit(x_train_fold, y_train_fold)
    lst_accu_stratified.append(accuracy_score(y_test_fold,clf.predict(x_test_fold)))
    lst_prec_stratified.append(precision_score(y_test_fold,clf.predict(x_test_fold), average = 'weighted'))
    lst_rec_stratified.append(recall_score(y_test_fold,clf.predict(x_test_fold), average = 'weighted'))
    lst_fscore_stratified.append(f1_score(y_test_fold,clf.predict(x_test_fold), average = 'weighted'))

# %%
acc = (sum(lst_accu_stratified)/len(lst_accu_stratified))
prec = (sum(lst_prec_stratified)/len(lst_prec_stratified))
rec = (sum(lst_rec_stratified)/len(lst_rec_stratified))
f1 = (sum(lst_fscore_stratified)/len(lst_fscore_stratified))
dict1 = {"Metric": ["Accuracy", "Precision", "Recall", "F1"], "Score":[acc,prec,rec,f1]}

metrics = pd.DataFrame(dict1)

# %%
metrics
# Out:
#       Metric     Score
# 0   Accuracy  0.875955
# 1  Precision  0.878920
# 2     Recall  0.875955
# 3         F1  0.875535

# %%
clf.fit(X, y)
# Out:
# SVC(kernel='linear', probability=True)

# %% [markdown]
# Decision Tree

# %%
clf = DecisionTreeClassifier()

# %%
lst_accu_stratified = []
lst_prec_stratified = []
lst_rec_stratified = []
lst_fscore_stratified = []

# %%
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=1)

for train_index, test_index in skf.split(X, y):
    x_train_fold, x_test_fold = X.iloc[train_index], X.iloc[test_index]
    y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]
    clf.fit(x_train_fold, y_train_fold)
    lst_accu_stratified.append(accuracy_score(y_test_fold,clf.predict(x_test_fold)))
    lst_prec_stratified.append(precision_score(y_test_fold,clf.predict(x_test_fold), average = 'weighted'))
    lst_rec_stratified.append(recall_score(y_test_fold,clf.predict(x_test_fold), average = 'weighted'))
    lst_fscore_stratified.append(f1_score(y_test_fold,clf.predict(x_test_fold), average = 'weighted'))

# %%
acc = (sum(lst_accu_stratified)/len(lst_accu_stratified))
prec = (sum(lst_prec_stratified)/len(lst_prec_stratified))
rec = (sum(lst_rec_stratified)/len(lst_rec_stratified))
f1 = (sum(lst_fscore_stratified)/len(lst_fscore_stratified))
dict1 = {"Metric": ["Accuracy", "Precision", "Recall", "F1"], "Score":[acc,prec,rec,f1]}

metrics = pd.DataFrame(dict1)

# %%
metrics
# Out:
#       Metric     Score
# 0   Accuracy  0.717060
# 1  Precision  0.723805
# 2     Recall  0.717060
# 3         F1  0.717680

# %%
clf.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Hierarchical

# %%
df = pd.read_csv('correlation_variance_filter/hierarchical/GSE13159.csv')

# %%
path = 'correlation_variance_filter/hierarchical/hierarchy_GSE13159.json'

# %% [markdown]
# Hierarchical Random Forest

# %%
import json
h = open(path,'r')
hierarchy = json.load(h)

# %%
clf = HierarquicalClassifier(hierarchy,
                                    RandomForestClassifier,
                                     {'bootstrap':True,
                                      'max_depth':50,
                                      'min_samples_leaf':1,
                                      'min_samples_split':2,
                                      'n_estimators':1000},
                                    False,
                                    None
                                    )

# %%
y_treino = df[list(hierarchy.keys())]
x_treino = df.drop(list(hierarchy.keys()), axis=1)

# %%
lst_accu_stratified = []
lst_prec_stratified = []
lst_rec_stratified = []
lst_fscore_stratified = []

# %%
import numpy as np
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=1)

# %%
columns = y_treino.columns
predict = pd.DataFrame()
y_treino['final'] = np.nan
for column in columns:
    y_treino['final'] = y_treino.apply(lambda x: x['final'] if pd.isnull(x[column]) else x[column], axis = 1)
# Out:
# <ipython-input-48-0d52a3aac363>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_treino['final'] = np.nan
# <ipython-input-48-0d52a3aac363>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_treino['final'] = y_treino.apply(lambda x: x['final'] if pd.isnull(x[column]) else x[column], axis = 1)
# <ipython-input-48-0d52a3aac363>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_treino['final'] = y_treino.apply(lambda x: x['final'] if pd.isnull(x[column]) else x[column], axis = 1)
# <ipython-input-48-0d52a3aac363>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_treino['final'] = y_treino.apply(lambda x: x['final'] if pd.isnull(x[column]) else x[column], axis = 1)

# %%
predict['final'] = list(y_treino['final'])
y_treino = y_treino.drop('final',axis=1)

# %%
for train_index, test_index in skf.split(x_treino,predict['final']):
    x_train_fold, x_test_fold = x_treino.iloc[train_index], x_treino.iloc[test_index]
    y_train_fold, y_test_fold = y_treino.iloc[train_index], predict.iloc[test_index]
    clf.fit(x_train_fold, y_train_fold)
    lst_accu_stratified.append(accuracy_score(list(y_test_fold['final']),clf.predict(x_test_fold)))
    lst_prec_stratified.append(precision_score(list(y_test_fold['final']),clf.predict(x_test_fold), average = 'weighted'))
    lst_rec_stratified.append(recall_score(list(y_test_fold['final']),clf.predict(x_test_fold), average = 'weighted'))
    lst_fscore_stratified.append(f1_score(list(y_test_fold['final']),clf.predict(x_test_fold), average = 'weighted'))


acc = (sum(lst_accu_stratified)/len(lst_accu_stratified))
prec = (sum(lst_prec_stratified)/len(lst_prec_stratified))
rec = (sum(lst_rec_stratified)/len(lst_rec_stratified))
f1 = (sum(lst_fscore_stratified)/len(lst_fscore_stratified))
dict1 = {"Metric": ["Accuracy", "Precision", "Recall", "F1"], "Score":[acc,prec,rec,f1]}
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
metrics = pd.DataFrame(dict1)

# %%
metrics
# Out:
#       Metric     Score
# 0   Accuracy  0.766696
# 1  Precision  0.741218
# 2     Recall  0.766696
# 3         F1  0.728231

# %%
clf.fit(x_treino, y_treino)
# Out:
# HierarquicalClassifier(clf=<class 'sklearn.ensemble._forest.RandomForestClassifier'>,
#                        feature_selection=False,
#                        hierarchy={'disease': {'root': ['Non-leukemia and '
#                                                        'healthy bone marrow',
#                                                        'Leukemia', 'MDS']},
#                                   'leukemia': {'Leukemia': ['CLL', 'ALL', 'AML',
#                                                             'CML']},
#                                   'subtypes': {'ALL': ['ALL with t(12;21)',
#                                                        'mature B-ALL with '
#                                                        't(8;14)',
#                                                        'c-ALL/Pre-B-ALL '
#                                                        'without t(9;22)',
#                                                        'T-ALL',...
#                                                        't(9;22)',
#                                                        'ALL with t(1;19)',
#                                                        'Pro-B-ALL with '
#                                                        't(11q23)/MLL'],
#                                                'AML': ['AML with t(15;17)',
#                                                        'AML complex aberrant '
#                                                        'karyotype',
#                                                        'AML with t(11q23)/MLL',
#                                                        'AML with normal '
#                                                        'karyotype + other '
#                                                        'abnormalities',
#                                                        'AML with t(8;21)',
#                                                        'AML with '
#                                                        'inv(16)/t(16;16)']}},
#                        max_features=None,
#                        params={'bootstrap': True, 'max_depth': 50,
#                                'min_samples_leaf': 1, 'min_samples_split': 2,
#                                'n_estimators': 1000})

# %% [markdown]
# Hierarchical SVM

# %%
import json
h = open(path,'r')
hierarchy = json.load(h)

# %%
clf = HierarquicalClassifier(hierarchy,
                                    SVC,
                                     {'kernel':'linear',
                                      'decision_function_shape':'ovr',
                                      'probability':True},
                                    False,
                                    None
                                    )

# %%
y_treino = df[list(hierarchy.keys())]
x_treino = df.drop(list(hierarchy.keys()), axis=1)

# %%
lst_accu_stratified = []
lst_prec_stratified = []
lst_rec_stratified = []
lst_fscore_stratified = []

# %%
import numpy as np
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=1)

# %%
columns = y_treino.columns
predict = pd.DataFrame()
y_treino['final'] = np.nan
for column in columns:
    y_treino['final'] = y_treino.apply(lambda x: x['final'] if pd.isnull(x[column]) else x[column], axis = 1)
# Out:
# <ipython-input-60-0d52a3aac363>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_treino['final'] = np.nan
# <ipython-input-60-0d52a3aac363>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_treino['final'] = y_treino.apply(lambda x: x['final'] if pd.isnull(x[column]) else x[column], axis = 1)
# <ipython-input-60-0d52a3aac363>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_treino['final'] = y_treino.apply(lambda x: x['final'] if pd.isnull(x[column]) else x[column], axis = 1)
# <ipython-input-60-0d52a3aac363>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_treino['final'] = y_treino.apply(lambda x: x['final'] if pd.isnull(x[column]) else x[column], axis = 1)

# %%
predict['final'] = list(y_treino['final'])
y_treino = y_treino.drop('final',axis=1)

# %%
for train_index, test_index in skf.split(x_treino,predict['final']):
    x_train_fold, x_test_fold = x_treino.iloc[train_index], x_treino.iloc[test_index]
    y_train_fold, y_test_fold = y_treino.iloc[train_index], predict.iloc[test_index]
    clf.fit(x_train_fold, y_train_fold)
    lst_accu_stratified.append(accuracy_score(list(y_test_fold['final']),clf.predict(x_test_fold)))
    lst_prec_stratified.append(precision_score(list(y_test_fold['final']),clf.predict(x_test_fold), average = 'weighted'))
    lst_rec_stratified.append(recall_score(list(y_test_fold['final']),clf.predict(x_test_fold), average = 'weighted'))
    lst_fscore_stratified.append(f1_score(list(y_test_fold['final']),clf.predict(x_test_fold), average = 'weighted'))


acc = (sum(lst_accu_stratified)/len(lst_accu_stratified))
prec = (sum(lst_prec_stratified)/len(lst_prec_stratified))
rec = (sum(lst_rec_stratified)/len(lst_rec_stratified))
f1 = (sum(lst_fscore_stratified)/len(lst_fscore_stratified))
dict1 = {"Metric": ["Accuracy", "Precision", "Recall", "F1"], "Score":[acc,prec,rec,f1]}

# %%
metrics = pd.DataFrame(dict1)

# %%
metrics
# Out:
#       Metric     Score
# 0   Accuracy  0.872137
# 1  Precision  0.874669
# 2     Recall  0.872137
# 3         F1  0.871539

# %%
clf.fit(x_treino, y_treino)
# Out:
# HierarquicalClassifier(clf=<class 'sklearn.svm._classes.SVC'>,
#                        feature_selection=False,
#                        hierarchy={'disease': {'root': ['Non-leukemia and '
#                                                        'healthy bone marrow',
#                                                        'Leukemia', 'MDS']},
#                                   'leukemia': {'Leukemia': ['CLL', 'ALL', 'AML',
#                                                             'CML']},
#                                   'subtypes': {'ALL': ['ALL with t(12;21)',
#                                                        'mature B-ALL with '
#                                                        't(8;14)',
#                                                        'c-ALL/Pre-B-ALL '
#                                                        'without t(9;22)',
#                                                        'T-ALL',
#                                                        'ALL with hyperdiploid '
#                                                        'k...
#                                                        'c-ALL/Pre-B-ALL with '
#                                                        't(9;22)',
#                                                        'ALL with t(1;19)',
#                                                        'Pro-B-ALL with '
#                                                        't(11q23)/MLL'],
#                                                'AML': ['AML with t(15;17)',
#                                                        'AML complex aberrant '
#                                                        'karyotype',
#                                                        'AML with t(11q23)/MLL',
#                                                        'AML with normal '
#                                                        'karyotype + other '
#                                                        'abnormalities',
#                                                        'AML with t(8;21)',
#                                                        'AML with '
#                                                        'inv(16)/t(16;16)']}},
#                        max_features=None,
#                        params={'decision_function_shape': 'ovr',
#                                'kernel': 'linear', 'probability': True})

# %% [markdown]
# Hierarchical Decision Tree

# %%
import json
h = open(path,'r')
hierarchy = json.load(h)

# %%
clf = HierarquicalClassifier(hierarchy,
                                    DecisionTreeClassifier,
                                     {},
                                    False,
                                    None
                                    )

# %%
y_treino = df[list(hierarchy.keys())]
x_treino = df.drop(list(hierarchy.keys()), axis=1)

# %%
lst_accu_stratified = []
lst_prec_stratified = []
lst_rec_stratified = []
lst_fscore_stratified = []

# %%
import numpy as np
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=1)

# %%
columns = y_treino.columns
predict = pd.DataFrame()
y_treino['final'] = np.nan
for column in columns:
    y_treino['final'] = y_treino.apply(lambda x: x['final'] if pd.isnull(x[column]) else x[column], axis = 1)
# Out:
# <ipython-input-72-0d52a3aac363>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_treino['final'] = np.nan
# <ipython-input-72-0d52a3aac363>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_treino['final'] = y_treino.apply(lambda x: x['final'] if pd.isnull(x[column]) else x[column], axis = 1)
# <ipython-input-72-0d52a3aac363>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_treino['final'] = y_treino.apply(lambda x: x['final'] if pd.isnull(x[column]) else x[column], axis = 1)
# <ipython-input-72-0d52a3aac363>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_treino['final'] = y_treino.apply(lambda x: x['final'] if pd.isnull(x[column]) else x[column], axis = 1)

# %%
predict['final'] = list(y_treino['final'])
y_treino = y_treino.drop('final',axis=1)

# %%
for train_index, test_index in skf.split(x_treino,predict['final']):
    x_train_fold, x_test_fold = x_treino.iloc[train_index], x_treino.iloc[test_index]
    y_train_fold, y_test_fold = y_treino.iloc[train_index], predict.iloc[test_index]
    clf.fit(x_train_fold, y_train_fold)
    lst_accu_stratified.append(accuracy_score(list(y_test_fold['final']),clf.predict(x_test_fold)))
    lst_prec_stratified.append(precision_score(list(y_test_fold['final']),clf.predict(x_test_fold), average = 'weighted'))
    lst_rec_stratified.append(recall_score(list(y_test_fold['final']),clf.predict(x_test_fold), average = 'weighted'))
    lst_fscore_stratified.append(f1_score(list(y_test_fold['final']),clf.predict(x_test_fold), average = 'weighted'))


acc = (sum(lst_accu_stratified)/len(lst_accu_stratified))
prec = (sum(lst_prec_stratified)/len(lst_prec_stratified))
rec = (sum(lst_rec_stratified)/len(lst_rec_stratified))
f1 = (sum(lst_fscore_stratified)/len(lst_fscore_stratified))
dict1 = {"Metric": ["Accuracy", "Precision", "Recall", "F1"], "Score":[acc,prec,rec,f1]}

# %%
metrics = pd.DataFrame(dict1)

# %%
metrics
# Out:
#       Metric     Score
# 0   Accuracy  0.704199
# 1  Precision  0.708445
# 2     Recall  0.704199
# 3         F1  0.703657

# %%
clf.fit(x_treino, y_treino)
# Out:
# HierarquicalClassifier(clf=<class 'sklearn.tree._classes.DecisionTreeClassifier'>,
#                        feature_selection=False,
#                        hierarchy={'disease': {'root': ['Non-leukemia and '
#                                                        'healthy bone marrow',
#                                                        'Leukemia', 'MDS']},
#                                   'leukemia': {'Leukemia': ['CLL', 'ALL', 'AML',
#                                                             'CML']},
#                                   'subtypes': {'ALL': ['ALL with t(12;21)',
#                                                        'mature B-ALL with '
#                                                        't(8;14)',
#                                                        'c-ALL/Pre-B-ALL '
#                                                        'without t(9;22)',
#                                                        'T-ALL',
#                                                        'ALL with hyperdiploid '
#                                                        'karyotype',
#                                                        'c-ALL/Pre-B-ALL with '
#                                                        't(9;22)',
#                                                        'ALL with t(1;19)',
#                                                        'Pro-B-ALL with '
#                                                        't(11q23)/MLL'],
#                                                'AML': ['AML with t(15;17)',
#                                                        'AML complex aberrant '
#                                                        'karyotype',
#                                                        'AML with t(11q23)/MLL',
#                                                        'AML with normal '
#                                                        'karyotype + other '
#                                                        'abnormalities',
#                                                        'AML with t(8;21)',
#                                                        'AML with '
#                                                        'inv(16)/t(16;16)']}},
#                        max_features=None, params={})

# %% [markdown]
# Adaboosting

# %%
import json
h = open(path,'r')
hierarchy = json.load(h)

# %%
clf = HierarquicalClassifier(hierarchy,
                                    AdaBoostClassifier,
                                     {'estimator':DecisionTreeClassifier(),
                                      'n_estimators':100,
                                      'random_state':0},
                                    False,
                                    None
                                    )

# %%
y_treino = df[list(hierarchy.keys())]
x_treino = df.drop(list(hierarchy.keys()), axis=1)

# %%
lst_accu_stratified = []
lst_prec_stratified = []
lst_rec_stratified = []
lst_fscore_stratified = []

# %%
import numpy as np
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=1)

# %%
columns = y_treino.columns
predict = pd.DataFrame()
y_treino['final'] = np.nan
for column in columns:
    y_treino['final'] = y_treino.apply(lambda x: x['final'] if pd.isnull(x[column]) else x[column], axis = 1)
# Out:
# <ipython-input-84-0d52a3aac363>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_treino['final'] = np.nan
# <ipython-input-84-0d52a3aac363>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_treino['final'] = y_treino.apply(lambda x: x['final'] if pd.isnull(x[column]) else x[column], axis = 1)
# <ipython-input-84-0d52a3aac363>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_treino['final'] = y_treino.apply(lambda x: x['final'] if pd.isnull(x[column]) else x[column], axis = 1)
# <ipython-input-84-0d52a3aac363>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_treino['final'] = y_treino.apply(lambda x: x['final'] if pd.isnull(x[column]) else x[column], axis = 1)

# %%
predict['final'] = list(y_treino['final'])
y_treino = y_treino.drop('final',axis=1)

# %%
for train_index, test_index in skf.split(x_treino,predict['final']):
    x_train_fold, x_test_fold = x_treino.iloc[train_index], x_treino.iloc[test_index]
    y_train_fold, y_test_fold = y_treino.iloc[train_index], predict.iloc[test_index]
    clf.fit(x_train_fold, y_train_fold)
    lst_accu_stratified.append(accuracy_score(list(y_test_fold['final']),clf.predict(x_test_fold)))
    lst_prec_stratified.append(precision_score(list(y_test_fold['final']),clf.predict(x_test_fold), average = 'weighted'))
    lst_rec_stratified.append(recall_score(list(y_test_fold['final']),clf.predict(x_test_fold), average = 'weighted'))
    lst_fscore_stratified.append(f1_score(list(y_test_fold['final']),clf.predict(x_test_fold), average = 'weighted'))


acc = (sum(lst_accu_stratified)/len(lst_accu_stratified))
prec = (sum(lst_prec_stratified)/len(lst_prec_stratified))
rec = (sum(lst_rec_stratified)/len(lst_rec_stratified))
f1 = (sum(lst_fscore_stratified)/len(lst_fscore_stratified))
dict1 = {"Metric": ["Accuracy", "Precision", "Recall", "F1"], "Score":[acc,prec,rec,f1]}

# %%
metrics = pd.DataFrame(dict1)

# %%
metrics
# Out:
#       Metric     Score
# 0   Accuracy  0.709929
# 1  Precision  0.717138
# 2     Recall  0.709929
# 3         F1  0.710360

# %%
clf.fit(x_treino, y_treino)
# Out:
# HierarquicalClassifier(clf=<class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>,
#                        feature_selection=False,
#                        hierarchy={'disease': {'root': ['Non-leukemia and '
#                                                        'healthy bone marrow',
#                                                        'Leukemia', 'MDS']},
#                                   'leukemia': {'Leukemia': ['CLL', 'ALL', 'AML',
#                                                             'CML']},
#                                   'subtypes': {'ALL': ['ALL with t(12;21)',
#                                                        'mature B-ALL with '
#                                                        't(8;14)',
#                                                        'c-ALL/Pre-B-ALL '
#                                                        'without t(9;22)',
#                                                        'T-...
#                                                        'c-ALL/Pre-B-ALL with '
#                                                        't(9;22)',
#                                                        'ALL with t(1;19)',
#                                                        'Pro-B-ALL with '
#                                                        't(11q23)/MLL'],
#                                                'AML': ['AML with t(15;17)',
#                                                        'AML complex aberrant '
#                                                        'karyotype',
#                                                        'AML with t(11q23)/MLL',
#                                                        'AML with normal '
#                                                        'karyotype + other '
#                                                        'abnormalities',
#                                                        'AML with t(8;21)',
#                                                        'AML with '
#                                                        'inv(16)/t(16;16)']}},
#                        max_features=None,
#                        params={'estimator': DecisionTreeClassifier(),
#                                'n_estimators': 100, 'random_state': 0})
